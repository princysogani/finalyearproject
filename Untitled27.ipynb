# %%
from tkinter import*
from PIL import ImageTk , Image
from selenium import webdriver
import pyttsx3
from selenium import webdriver
import time
import os
import cv2
import webbrowser
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer


global About
engine = pyttsx3.init()
engine.setProperty('volume',100)
engine.setProperty('rate',150)
n=0
items_list =os.listdir("imagesection")
def speak():
    values = Lb1.get(0,END)
    engine = pyttsx3.init()
    engine.setProperty('volume',100)
    engine.setProperty('rate',150)
    voices=engine.getProperty('voices')
    engine.setProperty('voice',voices[1].id)
        
    engine.say(values)
    engine.runAndWait()

    
def start():
    global boxes
    global Lb1
    boxes=Toplevel(box)
    boxes.geometry("900x600")
    Lb1=Listbox(boxes,bg = "black", bd = 10, fg = "white",font=("times new roman",18,"bold"),width=70) 
    Lb1.insert(1, "About")  
    Lb1.insert(2, "How does one apply?")  
    Lb1.insert(3, "On whose name the payments are to be made?")  
    Lb1.insert(4, "Is Banasthali Vidyapith residential?")  
    Lb1.insert(5, "Is Banasthali only for women?")  
    Lb1.insert(6, "What is the medium of instruction?")  
    Lb1.insert(7, "Does Banasthali offer distance learning program?")  
    Lb1.insert(8, "Does Banasthali Vidyapith has any other campus?") 
    Lb1.insert(9, "Does Banasthali Vidyapith provide Scholarship?")  
    Lb1.insert(10, "Can I study courses in Dance/Horse Riding/Gliding & Flying?")
    Lb1.insert(11, "Does Banasthali have a placement cell?")
    Lb1.insert(12, "How can I learn Fresco?")
    Lb1.insert(13, "School")
    Lb1.insert(14, "Hostels")
    Lb1.insert(15, "Fees Structure")
    Lb1.insert(16, "Campus")
    Lb1.place(x=0,y=0)
    
    def back():
        Lb1.delete(0,END)
        Lb1.insert(1, "About")  
        Lb1.insert(2, "How does one apply?")  
        Lb1.insert(3, "On whose name the payments are to be made?")  
        Lb1.insert(4, "Is Banasthali Vidyapith residential?")  
        Lb1.insert(5, "Is Banasthali only for women?")  
        Lb1.insert(6, "What is the medium of instruction?")  
        Lb1.insert(7, "Does Banasthali offer distance learning program?")  
        Lb1.insert(8, "Does Banasthali Vidyapith has any other campus?") 
        Lb1.insert(9, "Does Banasthali Vidyapith provide Scholarship?")  
        Lb1.insert(10, "Can I study courses in Dance/Horse Riding/Gliding & Flying?")
        Lb1.insert(11, "Does Banasthali have a placement cell?")
        Lb1.insert(12, "How can I learn Fresco?")
        Lb1.insert(13, "School")
        Lb1.insert(14, "Hostels")
        Lb1.insert(15, "Fees Structure")
        Lb1.insert(16, "Campus")
        
    
    def ans():
        global engine
        global value1
        values = Lb1.curselection()
        for i in values:
            value1=i
            
    
            if value1 == 0:
                Lb1.delete(0,END)
                #engine.say(textt)
                #engine.runAndWait()
                Lb1.insert(1,textt1)
                Lb1.insert(2,textt2)
                Lb1.insert(3,textt3)
                Lb1.insert(4,textt4)
                Lb1.insert(5,textt5)
                Lb1.insert(6,textt6)
                Lb1.insert(7,textt7)
                Lb1.insert(8,textt8)
                Lb1.insert(9,textt9)
                Lb1.insert(10,textt10)
                
               
            if value1==1:
                Lb1.delete(0,END)
                Lb1.insert(1,textt11)
                Lb1.insert(2,textt12)
                Lb1.insert(3,textt13)
                Lb1.insert(4,textt14)
                Lb1.insert(5,textt15)
                Lb1.insert(6,textt16)
                Lb1.insert(7,textt17) 
                
            if value1==2:
                Lb1.delete(0,END)
                Lb1.insert(1,textt18)
                Lb1.insert(2,textt19)
                
        
            if value1==3:
                Lb1.delete(0,END)
                Lb1.insert(1,textt20)
                Lb1.insert(2,textt21)
                
            if value1==5:
                Lb1.delete(0,END)
                Lb1.insert(1,textt22)
                Lb1.insert(2,textt23)
                Lb1.insert(3,textt24)
                Lb1.insert(4,textt25)
            if value1==4:
                Lb1.delete(0,END)
                Lb1.insert(1,textt26)
                Lb1.insert(2,textt27)
            if value1==6:
                Lb1.delete(0,END)
                Lb1.insert(1,textt28)
            if value1==7:
                Lb1.delete(0,END)
                Lb1.insert(1,textt29)
            if value1==8:
                Lb1.delete(0,END)
                Lb1.insert(1,textt30)
                Lb1.insert(2,textt31)
            if value1==9:
                Lb1.delete(0,END)
                Lb1.insert(1,textt32)
                Lb1.insert(2,textt33)
                Lb1.insert(3,textt34)
            if value1==10:
                Lb1.delete(0,END)
                Lb1.insert(1,textt35)
                Lb1.insert(2,textt36)
                Lb1.insert(3,textt37)
            if value1==11:
                Lb1.delete(0,END)
                Lb1.insert(1,textt38)
                Lb1.insert(2,textt39)
                
            if value1==12:
                Lb1.delete(0,END)
                Lb1.insert(1,textt40)
                Lb1.insert(2,textt41)
                Lb1.insert(3,textt42)
                Lb1.insert(4,textt43)
                Lb1.insert(5,textt44)
                Lb1.insert(6,textt45)
            if value1==13:
                Lb1.delete(0,END)
                Lb1.insert(1,textt46)
                Lb1.insert(2,textt47)
                Lb1.insert(3,textt48)
                Lb1.insert(4,textt49)
                Lb1.insert(5,textt50)
                Lb1.insert(6,textt51)
                Lb1.insert(7,textt52)
                Lb1.insert(8,textt53)
                Lb1.insert(9,textt54)
            if value1==14:
                Lb1.delete(0,END)
                Lb1.insert(1,textt55)
                Lb1.insert(2,textt56)
            if value1==15:
                Lb1.delete(0,END)
                Lb1.insert(1,textt57)
                Lb1.insert(2,textt58)
                Lb1.insert(3,textt59)
                Lb1.insert(4,textt60)
    
    
 
    button5 = Button(boxes,text= "ANSWER",font=("times new roman",20,"bold"),command=ans,bg="white",activebackground="white")
    button5.place(x=350,y=320)
    
    button7 = Button(boxes,text="SPEAK",font=("times new roman",18,"bold"),command=speak,bg="white",activebackground="white")
    button7.place(x=365,y=390)
    buttons = Button(boxes,text="BACK",font=("times new roman",18,"bold"),command=back,bg="white",activebackground="white")
    buttons.place(x=200,y=390)
    buttons1 = Button(boxes,text="EXIT",font=("times new roman",18,"bold"),command=boxes.destroy,bg="white",activebackground="white")
    buttons1.place(x=530,y=390)
    

def image():
    global screen3
    
    
    screen3 = Toplevel(box)
    screen3.title("IMAGE SECTION")
    screen3.geometry("450x250")
    def resize_image(screen3,copy_of_image,label1):
        new_height=250
        new_width = 450
        image = copy_of_image.resize((new_width,new_height))
        photo2 = ImageTk.PhotoImage(image)
        label1.configure(image=photo2)
        label1.image=photo2 #no garbage value
    def next():
        global n
        global items_list
        n=n+1
        img1 = items_list[n]
        print(img1)
        image = Image.open('./imagesection/'+img1)
        copy_of_image = image.copy()
        photo2 = ImageTk.PhotoImage(image)
        label2= Label(screen3,image=photo2)
        label2.bind('<configure>',resize_image(screen3,copy_of_image,label1))
        label2.pack()
    def previous():
        global n
        global items_list
        n=n-1
        img1 = items_list[n]
        
        image = Image.open('./imagesection/'+img1)
        copy_of_image = image.copy()
        photo2 = ImageTk.PhotoImage(image)
        label3= Label(screen3,image=photo2)
        label3.bind('<configure>',resize_image(screen3,copy_of_image,label1))
        label3.pack()
    n=0   
    items_list = os.listdir("imagesection")
    img1 = items_list[n]
    image = Image.open('./imagesection/'+img1)
    copy_of_image = image.copy()
    photo2 = ImageTk.PhotoImage(image)
    label1= Label(screen3,image=photo2)
    label1.bind('<configure>',resize_image(screen3,copy_of_image,label1))
    label1.pack()
    b1= Button(screen3,text=">>",width=5,height=2,command=next,bg="white",bd=2)
    b1.place(x=410,y=120)
    b2= Button(screen3,text="<<",width=5,height=2,command=previous,bg="white",bd=2)
    b2.place(x=2,y=120)
    
    
    
    
    

    
   
def chatbot():
    global box
    global engine
    box =Tk()
    def reply():
        bottext=question.get()
        textarea.insert(END,"\n"+"You searched "+bottext)
        question.delete(0,END)
        ssynth = pyttsx3.init()
        ssynth.setProperty('volume',100)
        ssynth.setProperty('rate',80)
        ssynth.say('searching on google'+bottext)
        ssynth.runAndWait()
    
        bottext = bottext.replace("_","+")
        browser=webdriver.Chrome()
        for i in range(1):
            elements=browser.get("https://www.google.com/search?q=" +bottext +" &start" +str(i))
            time.sleep(10) #10 seconds to see the results
            return elements
    
    
    About = "Banasthali Vidyapith is a fully residential women's higher education institute which offers an integrated system extending from the primary to the Ph.D. level.It was on October 6, 1935 that Smt. Ratan Shastri and Pandit Hiralal Shastri founded Banasthali to fill up the vacuum caused by the sudden death of their highly talented and promising daughter Shantabai. They had high expectations that she would work for women's cause when she would grow up. But  destiny  ordained  otherwise.Thus, Banasthali  owes its existence neither to the zeal of an educationist, nor to that of a social reformer. It is also not the creation of a Philanthropist's purse. It has arisen like the fabled phoenix from the ashes of a blossoming flower Shantabai."
    Apply = "The admission forms are normally available in the month of February onwards. The admission advertisements appear in the National and Regional Newspapers where all the details are given. You could get the form by sending Rs. 800/- by demand draft to The Secretary, Banasthali Vidyapith or paying cash Rs. 800/- in person and send the duly filled form by the Last Date given in the Admission Notice.Online Submission of application is also possible at the Banasthali Vidyapith's website.For detail please see the ADMISSIONS link of the website." 
    Payments= "The payments are not accepted by cheque. The draft can be drawn on any bank in favour of Banasthali Vidyapith payable at  Banasthali Vidyapith / Jaipur"
    residential = "It is a fully residential institution. The admission in hostel starts from class VI onwards."
    instruction = "Medium of instruction in school education is mainly Hindi. However we cater to the need of students who want to study in English medium by providing bilingual system - Instructions, Books and Question Papers are in English as well as Hindi. In Higher Education both English and Hindi are used as medium of instruction."
    women="Banasthali Vidyapith is only for women providing education from Nursery to Ph.D. level."
    distance="Banasthali Vidyapith does not offer any program under distance learning."
    anycampus="The  Banasthali Vidyapith presently not offering any other campus."
    scolarship="Yes, there are many schemes helping students financially such as scholarships, for details please see Financial Assistance."
    horseriding="Yes, you can if only you are a full time student of a regular course of Banasthali Vidyapith. All part time courses are open only to full time students of Banasthali Vidyapith."
    placement="Yes, Banasthali Vidyapith regularly attracts top Indian and multinational companies’ specially in the field of IT, Management, Biotechnology, Textile Design has a record of almost 100% placement."
    fresco="The Fresco camp is arranged for all the artists (male/female) in summer vacation (May/June). For details please contact  Dean, Fine Arts."
    school="The School firmly believes that textual studies are only but a part of the full development of a child and therefore provides a spectrum of in house activities through its program of panchmukhi shiksha. The main thrust of activities at the Vidyapith are visualized to promote the development of a balanced and harmonious personality of the students including physical, practical, aesthetic, moral and intellectual aspects."
    hostels="Banasthali University is a residential institution. A student admitted to the University will compulsorily have to join a hostel unless the student is ward of a worker of  the University and stays with him/her in the campus or the student belongs to a neighbouring village community within a radius of 2.5 Km. There are 31 student hostels in campus of the University. There is different number of rooms in each hostel ranging from 80 to 120. All rooms are well furnished with basic amenities provided. Each hostel has a separate Mess, Newspaper and Telephone facility One can see that all the hostels are named after 'Shanta bai' and students of the Banasthali are treated as the daughters of the University."
    fees="For fee structure go to official website of bansthali by clicking on website button above for more clearity you can search it on google"
    campus="Banasthali University has been a leading institution in the field of women education since 1935. The institution has an area extending to 850 acres having numerous buildings of different statures and sizes, housing various academic and administrative blocks."
    
    
    
    
    
    global textt1 
    global textt2
    global textt3 
    global textt4 
    global textt5
    global textt6
    global textt7
    global textt8 
    global textt9 
    global textt10 
    global textt11
    global textt12
    global textt13
    global textt14
    global textt15
    global textt16
    global textt17
    global textt18
    global textt19
    global textt20
    global textt21 
    global textt22 
    global textt23
    global textt24
    global textt25
    global textt26
    global textt27
    global textt28
    global textt29 
    global textt30 
    global textt31
    global textt32
    global textt33 
    global textt34
    global textt35
    global textt36
    global textt37
    global textt38
    global textt39
    global textt40
    global textt41 
    global textt42 
    global textt43
    global textt44
    global textt45
    global textt46
    global textt47
    global textt48 
    global textt49
    global textt50
    global textt51
    global textt52 
    global textt53
    global textt54
    global textt55
    global textt56
    global textt57
    global textt58
    global textt59
    global textt60 
    textt1 = "Banasthali Vidyapith is a fully residential women's higher education institute"
    textt2="which offers an integrated system extending from the primary to the Ph.D. level"
    textt3="It was on October 6, 1935 that Smt. Ratan Shastri and Pandit Hiralal Shastri"
    textt4="founded Banasthali to fill up the vacuum caused by the sudden death of their"
    textt5 ="highly talented and promising daughter Shantabai. They had high expectation"
    textt6="that she would work for women's cause when she would grow up. But  destiny"
    textt7="ordained  otherwise. Thus, Banasthali  owes its existence neither to the zeal of an"
    textt8="educationist, nor to that of a social reformer. It is also not the creation of a"
    textt9="Philanthropist's purse. It has arisen like the fabled phoenix from the ashes of a "
    textt10="blossoming flower Shantabai."
    textt11=" The admission forms are normally available in the month of February onwards."
    textt12="The admission advertisements appear in the National and Regional Newspapers"
    textt13="where all the details are given. You could get the form by sending Rs. 800/- by"
    textt14="demand draft to The Secretary, Banasthali Vidyapith or paying cash Rs. 800/- in"
    textt15="person. send the duly filled form by the Last Date given in the Admission Notice."
    textt16="and Online Submission of application is also possible at the Banasthali Vidyapith"
    textt17="website. For detail please see the ADMISSIONS link of the website."
    textt18="The payments are not accepted by cheque. The draft can be drawn on any bank in"
    textt19="favour of Banasthali Vidyapith payable at  Banasthali Vidyapith / Jaipur"
    textt20="It is a fully residential institution. The admission in hostel starts from class" 
    textt21="VI onwards"
    textt22="Medium of instruction in school education is mainly Hindi. However we cater to"
    textt23="the need of students who want to study in English medium by providing bilingual"
    textt24="system - Instructions, Books and Question Papers are in English as well as Hindi."
    textt25="In Higher Education both English and Hindi are used as medium of instruction."
    textt26="Banasthali Vidyapith is only for women providing education from Nursery to Ph.D."
    textt27="level."
    textt28="Banasthali Vidyapith does not offer any program under distance learning."
    textt29="The  Banasthali Vidyapith presently not offering any other campus."
    textt30="Yes, there are many schemes helping students financially such as scholarships,"
    textt31="for details please see Financial Assistance from website"
    textt32="Yes, you can if only you are a full time student of a regular course of Banasthali"
    textt33="Vidyapith. All part time courses are open only to full time students of Banasthali."
    textt34="To see the images of horse riding please go to image section."
    textt35="Yes, Banasthali Vidyapith regularly attracts top Indian and multinational"
    textt36="companies specially in the field of IT, Management, Biotechnology," 
    
    textt37="Textile Design has a record of almost 100% placement."
    textt38="The Fresco camp is arranged for all the artists (male/female) in summer"
    textt39="vacation (May/June). For details please contact  Dean, Fine Arts."
    textt40="The School firmly believes that textual studies are only but a part of the full"
    textt41="development of a child and therefore provides a spectrum of in house activities"
    textt42="through its program of panchmukhi shiksha. The main thrust of activities at the"
    textt43="Vidyapith are visualized to promote the development of a balanced and harmonious"
    textt44="personality of the students including physical, practical, aesthetic, moral and"
    textt45="intellectual aspects."
    textt46="Banasthali University is a residential institution. A student admitted to the"
    textt47="University will compulsorily have to join a hostel unless the student is ward of a"
    textt48="worker of  the University and stays with him/her in the campus or the student"
    textt49="belongs to a neighbouring village community within a radius of 2.5 Km. There are" 
    textt50="31 student hostels in campus of the University. There is different number of rooms" 
    textt51="in each hostel ranging from 80 to 120. All rooms are well furnished with basic"
    textt52="amenities provided.Each hostel has a separate Mess, Newspaper and Telephone"
    textt53="facility.One can see that all the hostel are named after 'Shanta bai' and students" 
    textt54="of the Banasthali are treated as the daughters of the University."
    textt55="For fee structure go to official website of bansthali by clicking on website"
    textt56="button above. For more clearity you can search it on google."
    textt57="Banasthali University has been a leading institution in the field of women"
    textt58="education since 1935. The institution has an area extending to 850 acres having"
    textt59="numerous buildings of different statures and sizes, housing various academic and"
    textt60="administrative blocks. For more click on image section above"

  
    
    
    
    
    
    
   
    
        
    def website():
        webbrowser.open("http://www.banasthali.org/")
    def video():
        webbrowser.open("https://www.youtube.com/watch?v=E-BIaJc7pq0")
    import time
    time.clock = time.time
    
    chatbot = ChatBot("bot")
    trainer = ListTrainer(chatbot)
    trainer.train([
        "hello bot",
        "Hello...please type your query to continue the chat",
    ])

    trainer.train([
        "what can i call you",
        "you can call me robotina",
    ])
    trainer.train([
        "name",
        "my name is robotina bot",
    ])
    trainer.train([
        "facilities",
        "BanasthaliVidyapith provides hostel facilities, playground, labs equipped with high end systems, 5 fold education,etc",
    ])
    trainer.train([
        "placements",
        "BanasthaliVidyapeeth is a very good college, and its placements are very good.\n But it depends on the students too. The highest package offered was 24 LPA,\n and the average package was about 6 LPA. Many companies come here, \n like IBM, TCS, Wipro etc.",
    ])
    trainer.train([
        "college timings",
        "SORRY! NO RESPONSE AVAILABLE",
    ])
    trainer.train([
        "departments",
        "Btech, commerce and management, journalism and mass communication, design, literature, research, BSc, BCA, Legal studies etc",
    ])
    trainer.train([
        "results info",
        "please go through the official website of banasthali",
    ])
    trainer.train([
        "about",
        "Banasthali Vidyapith is a university located in the Tonk district of the Rajasthan state in India. It is a deemed university offering programs at the secondary, senior secondary, undergraduate, and postgraduate degree levels",
    ])
    trainer.train([
        "location",
        "72 km. from Jaipur. 8 km. off. Jaipur-Kota Road at 65 km. stone. There are 14 buses of Rajasthan Roadways Transport Corporation at Jaipur-Banasthali route.",
    ])
    trainer.train([
        "images",
        "go to the image section left side",
    ])
    
    
            
        
            
        
             
        
            
    
    def send():
        
        a = question.get()
    
        ans=chatbot.get_response(a)
        
        textarea.insert(END,'\n\n\n')
        "\n\n\n\n"
        textarea.insert(END,'\t\t\t\t\t\t'+"you :"+a+'\n\n')
        textarea.insert(END,"bot :"+str(ans)+'\n')
        
        question.delete(0,END) 
    def clears():
        textarea.delete("1.0","end")
        
            
            
        
            
    box.geometry("1300x685+10+5")
    box.title("CHATBOT")
    box.config(bg="black")
    box.resizable(False,False)
    counts=0
    slider_text=''

    

    centerFrame =  Frame(box,bg="black")
    centerFrame.pack(side=RIGHT,fil="y")
    
    labels1 = Label(box,height=18,width=62,bg="black")
    labels1.place(x=5,y=90)
    
    textlabel1 = Label(labels1,text="QUICK INFORMATION ABOUT COLLEGE",fg="black",font=("Comic Sans MS",14,"bold"),borderwidth=3,relief="groove")
    textlabel1.place(x=0,y=0)
    
    

    textarea = Text(centerFrame,font=("Comic Sans MS",14,"bold"),height =30,width =70,wrap="word",highlightthickness=4,bg="light green")
    textarea.config(highlightbackground = "blue", highlightcolor= "blue")
    #textarea.tag_add('black',"1.0","1.92")
    #textarea.tag_configure("black",background="light blue",font=("Comic Sans MS",14,"bold"))
    textarea.pack(side=RIGHT)
    photo =(Image.open("C:\\Users\\LENOVO\\Pictures\\pic.png"))
    resize = photo.resize((70,70))
    new_img = ImageTk.PhotoImage(resize)

    
    
   
    
   


    
    

   

    labels = Label(box,text="BANASTHALI VIDYAPITH",fg="white",bg="black",font=("Comic Sans MS",18,"bold"),pady=5)
    labels.place(x=90,y=0)
     

    
    
    #photo = ImageTk.PhotoImage(Image.open("C:\\Users\\LENOVO\\Pictures\\pic.png"))
    #textarea.image_create(1.0,image=photo)


    
    text="hello students i am here to answer your query related to banasthali university"
    engine = pyttsx3.init()
    engine.setProperty('volume',100)
    engine.setProperty('rate',150)
    engine.say(text)
    engine.runAndWait()

    question = Entry(textarea,font =("Comic Sans MS",14,"bold"),width=48,highlightthickness=2)
    question.config(highlightbackground = "black", highlightcolor= "black")
    question.place(x=150,y=642)
    
    

    button1 = Button(labels1,text="GOOGLE SEARCH",font=("times new roman",12,"bold"),command=reply,fg="light blue",bg="black",border=0,activebackground="light blue")
    button1.place(x=0,y=40)

    button2 = Button(labels1,text="FAQ'S",font=("times new roman",12,"bold"),command=start,border=0,fg="light blue",bg="black",activebackground="light blue")
    button2.place(x=0,y=160)

    button3 = Button(labels1,text="IMAGE SECTION",font=("times new roman",12,"bold"),command=image,fg="light blue",bg="black",border=0,activebackground="light blue")
    button3.place(x=0,y=70)
    
    button4 = Button(labels1,text="WEBSITE",font=("times new roman",12,"bold"),command = website,fg="light blue",bg="black",border=0,activebackground="light blue")
    button4.place(x=0,y=100)
    
   
    
    button6= Button(labels1,text="VIDEO",font=("times new roman",12,"bold"),command=video,fg="light blue",bg="black",border=0,activebackground="light blue")
    button6.place(x=0,y=130)
    
    
    
    button9 = Button(box,text="SEND",font=("times new roman",14,"bold"),bg="light blue",bd=3,activebackground="light green",command=send)
    button9.place(x=1223,y=642)
    
    button10 = Button(textarea,text="clear",font=("times new roman",14,"bold"),bg="light green",activebackground="light green",command=clears)
    button10.place(x=0,y=0)
    
    labell = Label(textarea,text="Type Here:",fg="black",bg="light green",font=("Comic Sans MS",17,"bold"),relief="raised")
    labell.place(x=0,y=640)
    
    label = Label(textarea,image=new_img,bg="light green",fg="black")
    label.place(x=340,y=0)
    photosss = (Image.open("C:\\Users\\LENOVO\\Pictures\\Hnet.com-image (2).png"))
    resizesss = photosss.resize((70,70))
    new_imgs = ImageTk.PhotoImage(resizesss)
    labelsss = Label(box,image=new_imgs,bg="black")
    labelsss.place(x=0,y=0)
    pics = (Image.open("C:\\Users\\LENOVO\\Pictures\\pic.png"))
    resizepic = pics.resize((50,50))
    new_imagepic = ImageTk.PhotoImage(resizepic)
    labelpic = Label(box,image=new_imagepic,bg="black")
    labelpic.place(x=0,y=300) 
    labelas = Label(box,text="I'm Your Assistant",bg="black",fg="white",font=("Comic Sans MS",16,"bold"))
    labelas.place(x=60,y=300)
    labelasi = Label(box,text="you can ask me questions related to college",bg="black",fg="white",font=("Comic Sans MS",12,"bold"))
    labelasi.place(x=60,y=330)
    lab = Label(box,text="",height = 18,width=40,bg="black")
    lab.place(x=0,y=358)
    lab1 = Label(lab,text="about",font=("times new roman",14,"bold"),bg="black",fg="light blue")
    lab1.place(x=0,y=0)
    lab2 = Label(lab,text="facilities",font=("times new roman",14,"bold"),bg="black",fg="light blue")
    lab2.place(x=0,y=22)
    lab3 = Label(lab,text="placements",font=("times new roman",14,"bold"),bg="black",fg="light blue")
    lab3.place(x=0,y=44)
    
    lab5 = Label(lab,text="departments",font=("times new roman",14,"bold"),bg="black",fg="light blue")
    lab5.place(x=0,y=66)
    lab6 = Label(lab,text="results info",font=("times new roman",14,"bold"),bg="black",fg="light blue")
    lab6.place(x=0,y=88)
    lab7 = Label(lab,text="location",font=("times new roman",14,"bold"),bg="black",fg="light blue")
    lab7.place(x=0,y=110)
    lab8 = Label(lab,text="images",font=("times new roman",14,"bold"),bg="black",fg="light blue")
    lab8.place(x=0,y=132)
    box.mainloop()
chatbot()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# List Trainer: [##########          ] 50%
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# ...
